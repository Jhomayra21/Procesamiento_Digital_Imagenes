# %%
cadena = input("Ingresa una palabra o frase: ")

cadena_limpia = cadena.replace(" ", "").lower()
invertida = cadena_limpia[::-1]

if cadena_limpia == invertida:
    print("Es un palíndromo")
else:
    print("No es un palíndromo")
# Out:
# No es un palíndromo
